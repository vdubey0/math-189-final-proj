# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_theme()

# %%
walmart = pd.read_csv('data/walmart.csv')
amazon = pd.read_csv('data/amazon.csv')

# %%
walmart.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  019b67ef7f01103d8fb0a53e4c36daa7  2019-12-18 10:20:52 +0000
# 1  3a4ff306dcc8a6e2bf720964d29b84c3  2019-12-18 17:21:48 +0000
# 2  80090549d7d176327b186353c7b28ca4  2019-12-18 17:46:41 +0000
# 3  151ee1c61a29bacfedb01cd500494b2f  2019-12-18 22:14:22 +0000
# 4  7b2ef8d41f65df121f6b4b9828cf8dad  2019-12-18 06:56:02 +0000
#
#                                          Product Url  \
# 0  https://www.walmart.com/ip/La-Costena-Chipotle...
# 1  https://www.walmart.com/ip/Equate-Triamcinolon...
# 2  https://www.walmart.com/ip/AduroSmart-ERIA-Sof...
# 3  https://www.walmart.com/ip/24-Classic-Adjustab...
# 4  https://www.walmart.com/ip/Elephant-Shape-Sili...
#
#                                         Product Name  \
# 0     La Costena Chipotle Peppers, 7 OZ (Pack of 12)
# 1  Equate Triamcinolone Acetonide Nasal Allergy S...
# 2  AduroSmart ERIA Soft White Smart A19 Light Bul...
# ...

# %%
amazon.head()
# Out:
#                             Uniq Id  \
# 0  4c69b61db1fc16e7013b43fc926e502d
# 1  66d49bbed043f5be260fa9f7fbff5957
# 2  2c55cae269aebf53838484b0d7dd931a
# 3  18018b6bc416dab347b1b7db79994afa
# 4  e04b990e95bf73bbe6a3fa09785d7cd0
#
#                                         Product Name  Brand Name  Asin  \
# 0  DB Longboards CoreFlex Crossbow 41" Bamboo Fib...         NaN   NaN
# 1  Electronic Snap Circuits Mini Kits Classpack, ...         NaN   NaN
# 2  3Doodler Create Flexy 3D Printing Filament Ref...         NaN   NaN
# 3  Guillow Airplane Design Studio with Travel Cas...         NaN   NaN
# 4                   Woodstock- Collage 500 pc Puzzle         NaN   NaN
#
#                                             Category Upc Ean Code  List Price  \
# 0  Sports & Outdoors | Outdoor Recreation | Skate...          NaN         NaN
# 1  Toys & Games | Learning & Education | Science ...          NaN         NaN
# 2          Toys & Games | Arts & Crafts | Craft Kits          NaN         NaN
# ...

# %%
print(f'Walmart Cols: {list(walmart.columns)}')
print()
print(f'Amazon Cols: {list(amazon.columns)}')
# Out:
# Walmart Cols: ['Uniq Id', 'Crawl Timestamp', 'Product Url', 'Product Name', 'Description', 'List Price', 'Sale Price', 'Brand', 'Item Number', 'Gtin', 'Package Size', 'Category', 'Postal Code', 'Available']
#
# Amazon Cols: ['Uniq Id', 'Product Name', 'Brand Name', 'Asin', 'Category', 'Upc Ean Code', 'List Price', 'Selling Price', 'Quantity', 'Model Number', 'About Product', 'Product Specification', 'Technical Details', 'Shipping Weight', 'Product Dimensions', 'Image', 'Variants', 'Sku', 'Product Url', 'Stock', 'Product Details', 'Dimensions', 'Color', 'Ingredients', 'Direction To Use', 'Is Amazon Seller', 'Size Quantity Variant', 'Product Description']

# %%
walmart.isna().mean(axis=0)
# Out:
# Uniq Id            0.000000
# Crawl Timestamp    0.000000
# Product Url        0.000000
# Product Name       0.000000
# Description        0.001767
# List Price         0.000000
# Sale Price         0.000000
# Brand              0.018800
# Item Number        0.704167
# Gtin               0.000000
# Package Size       1.000000
# Category           0.000567
# Postal Code        1.000000
# Available          0.000000
# dtype: float64

# %%
amazon.isna().mean(axis=0)
# Out:
# Uniq Id                  0.000000
# Product Name             0.000000
# Brand Name               1.000000
# Asin                     1.000000
# Category                 0.082983
# Upc Ean Code             0.996601
# List Price               1.000000
# Selling Price            0.010698
# Quantity                 1.000000
# Model Number             0.177165
# About Product            0.027295
# Product Specification    0.163167
# Technical Details        0.078984
# Shipping Weight          0.113777
# Product Dimensions       0.952110
# Image                    0.000000
# Variants                 0.752250
# Sku                      1.000000
# Product Url              0.000000
# Stock                    1.000000
# Product Details          1.000000
# Dimensions               1.000000
# Color                    1.000000
# Ingredients              1.000000
# Direction To Use         1.000000
# Is Amazon Seller         0.000000
# Size Quantity Variant    1.000000
# ...

# %%
walmart = walmart[['Product Name', 'List Price', 'Sale Price', 'Brand', 'Category', 'Available']]
amazon = amazon[['Product Name', 'Brand Name', 'Category', 'Selling Price']]

# %%
extract_primary_category = lambda s: s.split(' | ')[0] if not pd.isna(s) else np.nan
walmart['Primary Category'] = walmart['Category'].apply(extract_primary_category)
amazon['Primary Category'] = amazon['Category'].apply(extract_primary_category)

# %%
walmart['Primary Category']
# Out:
# 0                     Food
# 1                   Health
# 2              Electronics
# 3        Sports & Outdoors
# 4                     Baby
#                ...
# 29995                 Food
# 29996    Sports & Outdoors
# 29997                 Food
# 29998               Beauty
# 29999               Beauty
# Name: Primary Category, Length: 30000, dtype: object

# %%
amazon['Primary Category']
# Out:
# 0        Sports & Outdoors
# 1             Toys & Games
# 2             Toys & Games
# 3             Toys & Games
# 4             Toys & Games
#                ...
# 9997          Toys & Games
# 9998          Toys & Games
# 9999       Office Products
# 10000         Toys & Games
# 10001       Home & Kitchen
# Name: Primary Category, Length: 10002, dtype: object

# %%
walmart = walmart.drop(columns=['Category'])
amazon = amazon.drop(columns=['Category'])

# %%
walmart.isna().mean(axis=0)
# Out:
# Product Name        0.000000
# List Price          0.000000
# Sale Price          0.000000
# Brand               0.018800
# Available           0.000000
# Primary Category    0.000567
# dtype: float64

# %%
walmart[walmart['Primary Category'].isna()]
# Out:
#                                             Product Name  List Price  \
# 3927   3 Stories Trading Company 6 Pack Boxed Receivi...       26.09
# 5868   Speed Racer Boomerangs RH (Blue)Colorado Boome...       16.95
# 6443                                Mobile Equipment Box      159.99
# 9068    Ultra Pro Magic: The Gathering Battebond Playmat       10.98
# 10449  Blood is Thicker than water- Family Runion you...       14.99
# 10671  adidas Kids Nemeziz 19.3 Indoor Soccer Shoes |...       60.00
# 13435  HERCHR Toy Bell Holder, Baby Crib Mobile Bed B...       26.74
# 14749  Bike Helmet Foldable Cycling Helmet Adult Road...       36.12
# 15946  Butterfinger Bites Chocolate Candy, 3.5oz Thea...        5.28
# 16538  Hawaii Lavender Hand Cleansing Sanitizer from ...        9.99
# 17378  Funkier Mens Firenze Short Sleeve Cycling Jers...       64.95
# 19279  Two/Three Layer 80cm / 90cm Fishing Rod Reel B...       22.29
# 21259  Professional Water Colours aureolin, 5 ml, 16 ...       26.44
# ...

# %%
plt.figure(figsize=(10, 10))
plt.hist(walmart[walmart['Primary Category'].isna()]['List Price'], bins=np.arange(0, 165, 5))
plt.xlabel('List Price')
plt.ylabel('Count')
plt.show()

# %%
amazon.isna().mean(axis=0)
# Out:
# Product Name        0.000000
# Brand Name          1.000000
# Selling Price       0.010698
# Primary Category    0.082983
# dtype: float64

# %%
def extract_price(s):
    if pd.isna(s):
        return np.nan
    
    s = s.replace('$', '').replace(',', '')
    if ' - ' in s:
        s1, s2 = s.split(' - ')
        s = (float(s1) + float(s2)) / 2
        return s
    try:
        return float(s)
    except:
        return np.nan

# %%
amazon['Selling Price'] = amazon['Selling Price'].apply(extract_price)

# %%
amazon = amazon.drop(amazon[amazon['Selling Price'].isna()].index)
amazon.shape
# Out:
# (9739, 4)

# %%
amazon[amazon['Primary Category'].isna()]
# Out:
#                                            Product Name  Brand Name  \
# 5     Terra by Battat – 4 Dinosaur Toys, Medium – Di...         NaN
# 9     Pokemon TCG: Sun and Moon Crimson Invasion Eli...         NaN
# 40    Funko Pop! Games: Persona 5 - The Joker (Style...         NaN
# 50    LAMO 5" Vinyl Figure - Legacy Gamers Dr Disres...         NaN
# 56    Wild Republic Mermaid Toy, Slap Bracelet, Gift...         NaN
# ...                                                 ...         ...
# 9876  NPW Drinking Buddies Money Shooter, It's Raini...         NaN
# 9877  Banpresto 39655 My Hero Academia Age of Heroes...         NaN
# 9884  Li'l Woodzeez Bakery Playset – Tickle-Your-Tas...         NaN
# 9936  Fisher-Price Nickelodeon Sunny Day, Sunny Styl...         NaN
# 9976  Beistle 55360-G FR Jumbo Crepe Streamer, 500-Feet         NaN
#
#       Selling Price Primary Category
# 5             18.66              NaN
# 9             38.49              NaN
# ...

# %%
plt.figure(figsize=(10, 10))
plt.hist(amazon[amazon['Primary Category'].isna()]['Selling Price'], bins=np.arange(0, 400, 10))
plt.xlabel('List Price')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(walmart['List Price'], bins=np.arange(0, 600, 10), alpha=0.5, density=True, label='Walmart')
plt.hist(amazon['Selling Price'], bins=np.arange(0, 600, 10), alpha=0.5, density=True, label='Amazon')
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(np.log(walmart['List Price'] + 10**-9), alpha=0.5, density=True, label='Walmart', bins=np.arange(-20, 20, 0.5))
plt.hist(np.log(amazon['Selling Price'] + 10**-9), alpha=0.5, density=True, label='Amazon', bins=np.arange(-20, 20, 0.5))
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
def generate_cdf(walmart_ser, amazon_ser, xlim=False):
    max_val = max(int(walmart_ser.max()), int(amazon_ser.max()))
    cdf_vals_wal = []
    cdf_vals_ama = []
    
    for i in np.arange(0, max_val + 1, 0.5):
        cdf_vals_wal.append((walmart_ser <= i).mean())
        cdf_vals_ama.append((amazon_ser <= i).mean())
        
    plt.figure(figsize=(20, 10))
    plt.plot(np.arange(0, max_val + 1, 0.5), cdf_vals_wal, label='Walmart')
    plt.plot(np.arange(0, max_val + 1, 0.5), cdf_vals_ama, label='Amazon')
    plt.legend()
    plt.xlabel('Prices')
    if xlim:
        plt.xlim(0, 500)
    plt.show()

# %%
generate_cdf(walmart['Sale Price'], amazon['Selling Price'])

# %%
generate_cdf(walmart['Sale Price'], amazon['Selling Price'], xlim=True)

# %%
walmart['List Price'].describe()
# Out:
# count    30000.000000
# mean        71.800136
# std        317.704824
# min          0.000000
# 25%         10.930000
# 50%         20.990000
# 75%         45.490000
# max      13280.810000
# Name: List Price, dtype: float64

# %%
amazon['Selling Price'].describe()
# Out:
# count    9739.000000
# mean       43.249241
# std       182.883767
# min         0.010000
# 25%         9.990000
# 50%        17.000000
# 75%        30.975000
# max      5332.000000
# Name: Selling Price, dtype: float64

# %%
walmart['Primary Category'].value_counts()
# Out:
# Primary Category
# Sports & Outdoors          11038
# Food                        4140
# Health                      3924
# Baby                        2754
# Personal Care               2313
# Household Essentials        1970
# Toys                         870
# Beauty                       808
# Home                         476
# Clothing                     446
# Premium Beauty               413
# Shop by Brand                158
# Patio & Garden               120
# Home Improvement             110
# Auto & Tires                  76
# Party & Occasions             75
# Pets                          74
# Electronics                   56
# Seasonal                      44
# Industrial & Scientific       30
# Feature                       15
# Books                         14
# Video Games                   12
# Jewelry                        8
# Arts Crafts & Sewing           8
# Walmart for Business           7
# Office Supplies                5
# Character Shop                 5
# ...

# %%
amazon['Primary Category'].value_counts()
# Out:
# Primary Category
# Toys & Games                                6509
# Home & Kitchen                               683
# Clothing, Shoes & Jewelry                    626
# Sports & Outdoors                            483
# Baby Products                                211
# Arts, Crafts & Sewing                        120
# Office Products                               75
# Hobbies                                       34
# Industrial & Scientific                       28
# Health & Household                            23
# Remote & App Controlled Vehicle Parts         22
# Remote & App Controlled Vehicles & Parts      17
# Tools & Home Improvement                      16
# Pet Supplies                                  14
# Patio, Lawn & Garden                          12
# Grocery & Gourmet Food                        11
# Beauty & Personal Care                        11
# Automotive                                     9
# Electronics                                    7
# ...

# %%
walmart_top_10_categories = list(walmart['Primary Category'].value_counts().index[:10])
amazon_top_10_categories = list(amazon['Primary Category'].value_counts().index[:10])

# %%
walmart['Primary Category'] = walmart['Primary Category'].apply(lambda cat: cat if cat in walmart_top_10_categories else 'Other')
amazon['Primary Category'] = amazon['Primary Category'].apply(lambda cat: cat if cat in amazon_top_10_categories else 'Other')

# %%
walmart_vcs = walmart['Primary Category'].value_counts()
walmart_vcs
# Out:
# Primary Category
# Sports & Outdoors       11038
# Food                     4140
# Health                   3924
# Baby                     2754
# Personal Care            2313
# Household Essentials     1970
# Other                    1261
# Toys                      870
# Beauty                    808
# Home                      476
# Clothing                  446
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x=walmart_vcs.index, y=walmart_vcs.values)
# Out:
# <AxesSubplot:xlabel='Primary Category'>

# %%
amazon_vcs = amazon['Primary Category'].value_counts()

# %%
plt.figure(figsize=(24, 10))
sns.barplot(x=amazon_vcs.index, y=amazon_vcs.values)
# Out:
# <AxesSubplot:xlabel='Primary Category'>

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=walmart, x='Primary Category', y='Sale Price')
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=walmart, x='Primary Category', y='Sale Price')
plt.ylim(0, 200)
plt.show()

# %%
plt.figure(figsize=(24, 10))
sns.boxplot(data=amazon, x='Primary Category', y='Selling Price')
plt.show()

# %%
plt.figure(figsize=(24, 10))
sns.boxplot(data=amazon, x='Primary Category', y='Selling Price')
plt.ylim(0, 200)
plt.show()

# %%
walmart['Primary Category'].unique()
# Out:
# array(['Food', 'Health', 'Other', 'Sports & Outdoors', 'Baby', 'Home',
#        'Household Essentials', 'Clothing', 'Personal Care', 'Toys',
#        'Beauty'], dtype=object)

# %%
amazon['Primary Category'].unique()
# Out:
# array(['Sports & Outdoors', 'Toys & Games', 'Other',
#        'Clothing, Shoes & Jewelry', 'Home & Kitchen', 'Baby Products',
#        'Arts, Crafts & Sewing', 'Office Products', 'Health & Household',
#        'Industrial & Scientific', 'Hobbies'], dtype=object)

# %%
plt.figure(figsize=(20, 10))
plt.hist(walmart[walmart['Primary Category'] == 'Sports & Outdoors']['Sale Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='walmart')
plt.hist(amazon[amazon['Primary Category'] == 'Sports & Outdoors']['Selling Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='amazon')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(walmart[walmart['Primary Category'] == 'Toys']['Sale Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='walmart')
plt.hist(amazon[amazon['Primary Category'] == 'Toys & Games']['Selling Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='amazon')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(walmart[walmart['Primary Category'].isin(['Health', 'Household Essentials', 'Home'])]['Sale Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='walmart')
plt.hist(amazon[amazon['Primary Category'].isin(['Home & Kitchen', 'Health & Household'])]['Selling Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='amazon')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(walmart[walmart['Primary Category'] == 'Clothing']['Sale Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='walmart')
plt.hist(amazon[amazon['Primary Category'] == 'Clothing, Shoes & Jewelry']['Selling Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='amazon')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(walmart[walmart['Primary Category'] == 'Baby']['Sale Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='walmart')
plt.hist(amazon[amazon['Primary Category'] == 'Baby Products']['Selling Price'], density=True, bins = np.arange(0, 1000, 10), alpha=0.5, label='amazon')
plt.legend()
plt.show()
